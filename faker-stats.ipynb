# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session

# %%
from bs4 import BeautifulSoup
import requests

# %%
page = requests.get("https://lol.fandom.com/wiki/Special:RunQuery/TournamentStatistics?TS%5Bpreload%5D=PlayerByChampion&TS%5Btournament%5D=&TS%5Blink%5D=Faker&TS%5Bchampion%5D=&TS%5Brole%5D=&TS%5Bteam%5D=&TS%5Bpatch%5D=&TS%5Byear%5D=&TS%5Bregion%5D=&TS%5Btournamentlevel%5D=&TS%5Bwhere%5D=&TS%5Bincludelink%5D%5Bis_checkbox%5D=true&TS%5Bshownet%5D%5Bis_checkbox%5D=true&_run=&pfRunQueryFormName=TournamentStatistics&wpRunQuery=&pf_free_text=")

# %%
soup = BeautifulSoup(page.text, 'html5lib')

# %%
dfs = pd.read_html(page.text)[0]

# %%
dfs
# Out:
#                                                   Player: Faker - Showing Values Per Game  \
#    1095 Total Games Played on 77 Champions (On ⁠⁠SKT 2⁠⁠SKT⁠⁠SKT K⁠⁠Fire⁠⁠LCK (+ 5 More))
#                                                                                  Champion
# 0                                                Azir
# 1                                                Ryze
# 2                                             Orianna
# 3                                             LeBlanc
# 4                                               Galio
# ..                                                ...
# 74                                           Pantheon
# 75                                              Quinn
# 76                                             Singed
# 77                                           Overall:
# 78                                             Total:
#
#                                                                               \
#
#        G    W    L     WR        K        D        A   KDA         CS   CS/M
# 0    115   75   40  65.2%     3.32     2.09     5.08  4.03     319.94    9.3
# 1     75   47   28  62.7%     3.56     2.07     5.00  4.14     332.84    9.5
# 2     73   47   26  64.4%     3.48     2.26     6.34  4.35     325.26      -
# 3     58   48   10  82.8%     4.95     1.67     5.07  5.99     269.64   7.92
# 4     51   34   17  66.7%     2.29     1.90     6.25  4.49     318.02   9.21
# ..   ...  ...  ...    ...      ...      ...      ...   ...        ...    ...
# 74     1    0    1     0%     3.00     5.00     2.00     1     210.00   7.19
# 75     1    0    1     0%     2.00     2.00     0.00     1     287.00  10.19
# 76     1    0    1     0%     0.00     2.00     0.00     0     317.00   8.26
# 77     -    -    -      -     3.61     2.04     5.39  4.41     308.33      -
# 78  1095  744  351  67.9%  3948.00  2236.00  5904.00     -  337619.00      -
#
#
#
#      G.1  G/M   KPAR     KS     GS
# 0   14.5  422  64.4%  25.4%  22.8%
# 1      -    -      -      -      -
# 2      -    -      -      -      -
# 3      -    -      -      -      -
# 4   13.8  399  72.4%  19.4%  21.4%
# ..   ...  ...    ...    ...    ...
# 74   9.4  322  62.5%  37.5%  20.3%
# 75    11  391   100%   100%  25.5%
# 76  12.1  314     0%     0%  20.8%
# 77     -    -      -      -      -
# 78     -    -      -      -      -
#
# [79 rows x 16 columns]

# %%
dfs.describe()
# Out:
#                                                      Player: Faker - Showing Values Per Game  \
#       1095 Total Games Played on 77 Champions (On ⁠⁠SKT 2⁠⁠SKT⁠⁠SKT K⁠⁠Fire⁠⁠LCK (+ 5 More))
#                                                                                            K
# count                                          79.000000
# mean                                           53.652532
# std                                           443.769146
# min                                             0.000000
# 25%                                             2.660000
# 50%                                             3.500000
# 75%                                             4.920000
# max                                          3948.000000
#
#
#
#                  D            A             CS
# count    79.000000    79.000000      79.000000
# mean     30.512911    79.888987    4564.111646
# std     251.320210   663.667223   37952.041594
# min       0.000000     0.000000      30.000000
# 25%       1.700000     4.230000     267.250000
# 50%       2.030000     5.000000     294.800000
# 75%       2.500000     6.295000     326.130000
# max    2236.000000  5904.000000  337619.000000

# %%
dfs.to_csv('faker-stats-champion.csv')

# %% [markdown]
# Okay, so here I've used the `BeautifulSoup` package to scrape some data from the lol esports fandom wiki. There is no website I've found that just shows Faker's (or anyone elses) complete match history. Thus, I have to scrape from multiple tables and use a lot of dataframe joining to get the match history. It's not complete but I will have to do. There must be a way to piece together the information.
#
# What I can do is get a list of tournaments Faker played in, then go to each of those tournaments, scrape the match history from those tournaments, and only look for Faker's games.
#
# Actually, now that I think about it, Iprobably want to start by scraping the match history from every tournament ever. This way, I can filter the match history for certain teams and players so that things will be slightly easier in the future.
#
# I plan to work on this a little bit every day. It may take a few years, but this seems like it'll be an interesting project.

# %% [markdown]
# Also, a lot of missing data. Oof. Hopefully I can use tournament data to get the results.

# %% [markdown]
# Welp, time to get the tournament data

# %%
tournament_page = requests.get("https://lol.fandom.com/wiki/Faker/Tournament_Results")
soup_tournaments = BeautifulSoup(tournament_page.text, "html5lib") # get the html

# %%
tournaments = pd.read_html(tournament_page.text)[5]
tournaments
# Out:
#    Faker Tournament Results                                           \
#                        Date     Pl                             Event
# 0                2022-08-14      2                   LCK 2022 Summer
# 1                2022-05-29      2                          MSI 2022
# 2                2022-04-02      1          LCK 2022 Spring Playoffs
# 3                2022-03-20      1                   LCK 2022 Spring
# 4                2021-10-30  3 - 4                       Worlds 2021
# ..                      ...    ...                               ...
# 65               2013-09-07      1    Korea Regional Finals Season 3
# 66               2013-08-31      1             Champions 2013 Summer
# 67               2013-06-29  3 - 4           AMD-INVEN GamExperience
# 68               2013-06-15      3             Champions 2013 Spring
# 69               2013-03-23      Q  Champions 2013 Spring Qualifiers
#
#
#      Last Result     Team                                             Roster
# 0     15 - 3⁠⁠RR     ⁠⁠T1   Zeus, Oner, Faker, Gumayusi, Keria, Polt, moment
# 1     2 : 3⁠⁠RNG     ⁠⁠T1   Zeus, Oner, Faker, Gumayusi, Keria, Polt, moment
# 2     3 : 1⁠⁠GEN     ⁠⁠T1   Zeus, Oner, Faker, Gumayusi, Keria, Polt, moment
# 3     18 - 0⁠⁠RR     ⁠⁠T1   Zeus, Oner, Faker, Gumayusi, Keria, Polt, moment
# 4      2 : 3⁠⁠DK     ⁠⁠T1  Canna, Oner, Faker, Gumayusi, Keria, Stardust,...
# ..           ...      ...                                                ...
# 65   3 : 1⁠⁠KT.B    ⁠⁠SKT     Impact, bengi, Faker, Piglet, PoohManDu, kkOma
# 66   3 : 2⁠⁠KT.B  ⁠⁠SKT 2     Impact, bengi, Faker, Piglet, PoohManDu, kkOma
# 67  0 : 2⁠⁠MVP.O  ⁠⁠SKT 2     Impact, bengi, Faker, Piglet, PoohManDu, kkOma
# 68    3 : 0⁠⁠CJF  ⁠⁠SKT 2     Impact, bengi, Faker, Piglet, PoohManDu, kkOma
# 69   2 : 0⁠⁠BEGG  ⁠⁠SKT 2            Impact, bengi, Faker, Piglet, PoohManDu
#
# [70 rows x 6 columns]

# %%
tournaments = tournaments.droplevel(level=0, axis=1)
tournaments
# Out:
#           Date     Pl                             Event   Last Result  \
# 0   2022-08-14      2                   LCK 2022 Summer    15 - 3⁠⁠RR
# 1   2022-05-29      2                          MSI 2022    2 : 3⁠⁠RNG
# 2   2022-04-02      1          LCK 2022 Spring Playoffs    3 : 1⁠⁠GEN
# 3   2022-03-20      1                   LCK 2022 Spring    18 - 0⁠⁠RR
# 4   2021-10-30  3 - 4                       Worlds 2021     2 : 3⁠⁠DK
# ..         ...    ...                               ...           ...
# 65  2013-09-07      1    Korea Regional Finals Season 3   3 : 1⁠⁠KT.B
# 66  2013-08-31      1             Champions 2013 Summer   3 : 2⁠⁠KT.B
# 67  2013-06-29  3 - 4           AMD-INVEN GamExperience  0 : 2⁠⁠MVP.O
# 68  2013-06-15      3             Champions 2013 Spring    3 : 0⁠⁠CJF
# 69  2013-03-23      Q  Champions 2013 Spring Qualifiers   2 : 0⁠⁠BEGG
#
#        Team                                             Roster
# 0      ⁠⁠T1   Zeus, Oner, Faker, Gumayusi, Keria, Polt, moment
# 1      ⁠⁠T1   Zeus, Oner, Faker, Gumayusi, Keria, Polt, moment
# 2      ⁠⁠T1   Zeus, Oner, Faker, Gumayusi, Keria, Polt, moment
# 3      ⁠⁠T1   Zeus, Oner, Faker, Gumayusi, Keria, Polt, moment
# 4      ⁠⁠T1  Canna, Oner, Faker, Gumayusi, Keria, Stardust,...
# ..      ...                                                ...
# 65    ⁠⁠SKT     Impact, bengi, Faker, Piglet, PoohManDu, kkOma
# 66  ⁠⁠SKT 2     Impact, bengi, Faker, Piglet, PoohManDu, kkOma
# 67  ⁠⁠SKT 2     Impact, bengi, Faker, Piglet, PoohManDu, kkOma
# 68  ⁠⁠SKT 2     Impact, bengi, Faker, Piglet, PoohManDu, kkOma
# 69  ⁠⁠SKT 2            Impact, bengi, Faker, Piglet, PoohManDu
#
# [70 rows x 6 columns]

# %% [markdown]
# I can't believe Faker has played in 70 tournaments. That's crazy. He's the GOAT for a reason.

# %%
tournaments.reset_index(level=None, drop=False, inplace=False, col_level=0, col_fill="")
# Out:
#     index        Date     Pl                             Event   Last Result  \
# 0       0  2022-08-14      2                   LCK 2022 Summer    15 - 3⁠⁠RR
# 1       1  2022-05-29      2                          MSI 2022    2 : 3⁠⁠RNG
# 2       2  2022-04-02      1          LCK 2022 Spring Playoffs    3 : 1⁠⁠GEN
# 3       3  2022-03-20      1                   LCK 2022 Spring    18 - 0⁠⁠RR
# 4       4  2021-10-30  3 - 4                       Worlds 2021     2 : 3⁠⁠DK
# ..    ...         ...    ...                               ...           ...
# 65     65  2013-09-07      1    Korea Regional Finals Season 3   3 : 1⁠⁠KT.B
# 66     66  2013-08-31      1             Champions 2013 Summer   3 : 2⁠⁠KT.B
# 67     67  2013-06-29  3 - 4           AMD-INVEN GamExperience  0 : 2⁠⁠MVP.O
# 68     68  2013-06-15      3             Champions 2013 Spring    3 : 0⁠⁠CJF
# 69     69  2013-03-23      Q  Champions 2013 Spring Qualifiers   2 : 0⁠⁠BEGG
#
#        Team                                             Roster
# 0      ⁠⁠T1   Zeus, Oner, Faker, Gumayusi, Keria, Polt, moment
# 1      ⁠⁠T1   Zeus, Oner, Faker, Gumayusi, Keria, Polt, moment
# 2      ⁠⁠T1   Zeus, Oner, Faker, Gumayusi, Keria, Polt, moment
# 3      ⁠⁠T1   Zeus, Oner, Faker, Gumayusi, Keria, Polt, moment
# 4      ⁠⁠T1  Canna, Oner, Faker, Gumayusi, Keria, Stardust,...
# ..      ...                                                ...
# 65    ⁠⁠SKT     Impact, bengi, Faker, Piglet, PoohManDu, kkOma
# 66  ⁠⁠SKT 2     Impact, bengi, Faker, Piglet, PoohManDu, kkOma
# 67  ⁠⁠SKT 2     Impact, bengi, Faker, Piglet, PoohManDu, kkOma
# 68  ⁠⁠SKT 2     Impact, bengi, Faker, Piglet, PoohManDu, kkOma
# 69  ⁠⁠SKT 2            Impact, bengi, Faker, Piglet, PoohManDu
#
# [70 rows x 7 columns]

# %%
# list of tournaments to scrape data from
tournaments.columns
# Out:
# Index(['Date', 'Pl', 'Event', 'Last Result', 'Team', 'Roster'], dtype='object')

# %%
tournaments['index'] = range(70, 0, -1)
tournaments.rename(columns={'index':'Tournament Number'}, inplace=True)
tournaments
# Out:
#           Date     Pl                             Event   Last Result  \
# 0   2022-08-14      2                   LCK 2022 Summer    15 - 3⁠⁠RR
# 1   2022-05-29      2                          MSI 2022    2 : 3⁠⁠RNG
# 2   2022-04-02      1          LCK 2022 Spring Playoffs    3 : 1⁠⁠GEN
# 3   2022-03-20      1                   LCK 2022 Spring    18 - 0⁠⁠RR
# 4   2021-10-30  3 - 4                       Worlds 2021     2 : 3⁠⁠DK
# ..         ...    ...                               ...           ...
# 65  2013-09-07      1    Korea Regional Finals Season 3   3 : 1⁠⁠KT.B
# 66  2013-08-31      1             Champions 2013 Summer   3 : 2⁠⁠KT.B
# 67  2013-06-29  3 - 4           AMD-INVEN GamExperience  0 : 2⁠⁠MVP.O
# 68  2013-06-15      3             Champions 2013 Spring    3 : 0⁠⁠CJF
# 69  2013-03-23      Q  Champions 2013 Spring Qualifiers   2 : 0⁠⁠BEGG
#
#        Team                                             Roster  \
# 0      ⁠⁠T1   Zeus, Oner, Faker, Gumayusi, Keria, Polt, moment
# 1      ⁠⁠T1   Zeus, Oner, Faker, Gumayusi, Keria, Polt, moment
# 2      ⁠⁠T1   Zeus, Oner, Faker, Gumayusi, Keria, Polt, moment
# 3      ⁠⁠T1   Zeus, Oner, Faker, Gumayusi, Keria, Polt, moment
# 4      ⁠⁠T1  Canna, Oner, Faker, Gumayusi, Keria, Stardust,...
# ..      ...                                                ...
# 65    ⁠⁠SKT     Impact, bengi, Faker, Piglet, PoohManDu, kkOma
# 66  ⁠⁠SKT 2     Impact, bengi, Faker, Piglet, PoohManDu, kkOma
# 67  ⁠⁠SKT 2     Impact, bengi, Faker, Piglet, PoohManDu, kkOma
# 68  ⁠⁠SKT 2     Impact, bengi, Faker, Piglet, PoohManDu, kkOma
# 69  ⁠⁠SKT 2            Impact, bengi, Faker, Piglet, PoohManDu
#
#     Tournament Number
# 0                  70
# 1                  69
# 2                  68
# 3                  67
# 4                  66
# ..                ...
# 65                  5
# 66                  4
# 67                  3
# 68                  2
# 69                  1
#
# [70 rows x 7 columns]

# %%
standings = tournaments.loc[:, 'Last Result']
standing_number = 0
for standing in standings:
    index = 0
    for ch in standing:
        if ord(ch) >= 65 and ord(ch) <= 90:
            standings[standing_number] = standing[:index] + " " + standing[index:]
            break
        index += 1
    standing_number += 1
standings = standings.to_numpy()
count = 0
for standing in standings:
    standing = standing.encode('ascii', 'ignore').decode('utf-8').strip()
    # print(standing)
    temp = standing.split()
    standing = ' '.join(temp)
    standings[count] = standing
    count += 1
standings
# Out:
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   import sys
# array(['15 - 3 RR', '2: 3 RNG', '3: 1 GEN', '18 - 0 RR', '2: 3 DK',
#        '3: 2 HLE', '1: 3 DK', '11 - 7 RR', '0: 3 GEN', '11 - 7 RR',
#        '0: 3 GEN', '1: 2 AF', '13 - 5 RR', '1 - 2 RR', '3: 0 GEN',
#        '14 - 4 RR', '1: 3 SB', '1: 3 G2', '3: 1 GRF', '11 - 7 RR',
#        '3: 1 LPL', '2: 3 G2', '3: 0 GRF', '14 - 4 RR', '1: 2 DWG',
#        '2: 3 GEN', '1: 3 CHN', '8 - 10 RR', '2: 3 LPL', '8 - 2 RR',
#        '1: 3 KT', '9 - 9 RR', '1: 2 LPL', '0: 2 LZ', '0: 3 SSG',
#        '1: 3 LZ', '13 - 5 RR', '1: 3 LPL', '3: 1 G2', '3: 0 KT',
#        '16 - 2 RR', '0: 2 ROX', '3: 2 SSG', '2: 3 KT', '13 - 5 RR',
#        '3: 0 CLG', '3: 1 ROX', '12 - 6 RR', '3: 0 FNC', '0: 2 ESC',
#        '3: 1 KOO', '3: 0 KT', '17 - 1 RR', '2: 3 EDG', '3: 0 GET',
#        '11 - 3 RR', '4-1-0 RR', '1: 3 NJWS', '1: 3 SSW', '3: 0 NJBS',
#        '3: 0 KT.B', '3: 0 OMG', '1: 3 SSO', '3: 0 SSO', '3: 0 RYL',
#        '3: 1 KT.B', '3: 2 KT.B', '0: 2 MVP.O', '3: 0 CJF', '2: 0 BEGG'],
#       dtype=object)
